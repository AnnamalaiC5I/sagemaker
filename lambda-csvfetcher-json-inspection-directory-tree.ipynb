# %%
def get_cfn_style_config(stage_config):
    parameters = []
    for key, value in stage_config["Parameters"].items():
        parameter = {
            "ParameterKey": key,
            "ParameterValue": value
        }
        parameters.append(parameter)
    tags = []
    for key, value in stage_config["Tags"].items():
        tag = {
            "Key": key,
            "Value": value
        }
        tags.append(tag)
    return parameters, tags

def create_cfn_params_tags_file(config, export_params_file, export_tags_file):
    # Write Params and tags in separate file for Cfn cli command
    parameters, tags = get_cfn_style_config(config)
    with open(export_params_file, "w") as f:
        json.dump(parameters, f, indent=4)
    with open(export_tags_file, "w") as f:
        json.dump(tags, f, indent=4)

# %%
import json

f = open(r"C:\Users\annamalai\Downloads\vaibhav's copy code\extended-stage-config.json")

data = json.load(f)

# %%
parameters, tags = get_cfn_style_config(data)

# %%
parameters
# Out:
# [{'ParameterKey': 'StageName', 'ParameterValue': 'staging'},
#  {'ParameterKey': 'EndpointInstanceCount', 'ParameterValue': '1'},
#  {'ParameterKey': 'EndpointInstanceType', 'ParameterValue': 'ml.m5.large'},
#  {'ParameterKey': 'SamplingPercentage', 'ParameterValue': '100'},
#  {'ParameterKey': 'EnableDataCapture', 'ParameterValue': 'true'},
#  {'ParameterKey': 'SageMakerProjectName', 'ParameterValue': 'project-x6'},
#  {'ParameterKey': 'ModelPackageName',
#   'ParameterValue': 'arn:aws:sagemaker:ap-south-1:294897175072:model-package/project-x6-p-tp8lsnxnforl/1'},
#  {'ParameterKey': 'ModelExecutionRoleArn',
#   'ParameterValue': 'arn:aws:iam::294897175072:role/service-role/AmazonSageMakerServiceCatalogProductsUseRole'},
#  {'ParameterKey': 'DataCaptureUploadPath',
#   'ParameterValue': 's3://sagemaker-project-p-tp8lsnxnforl/datacapture-staging'}]

# %%
tags
# Out:
# [{'Key': 'sagemaker:deployment-stage', 'Value': 'staging'},
#  {'Key': 'sagemaker:project-id', 'Value': 'p-tp8lsnxnforl'},
#  {'Key': 'sagemaker:project-name', 'Value': 'project-x6'},
#  {'Key': 'sagemaker:user-profile-arn',
#   'Value': 'arn:aws:sagemaker:ap-south-1:294897175072:user-profile/d-uwasxowh3d5n/default-1685940998555'},
#  {'Key': 'sagemaker:domain-arn',
#   'Value': 'arn:aws:sagemaker:ap-south-1:294897175072:domain/d-uwasxowh3d5n'}]

# %%
import pandas as pd

# %%
df = pd.DataFrame({'sepal_length' : [5.7,4.5], 'sepal_width' : [2.8,1],'petal_length':[4.5,3.4],'petal_width':[1.3,2.0]})

# %%
import io
from io import StringIO
csv_file = io.StringIO()
# by default sagemaker expects comma seperated
df.to_csv(csv_file, sep=",", header=False, index=False)
my_payload_as_csv = csv_file.getvalue()

# %%
my_payload_as_csv
# Out:
# '5.7,2.8,4.5,1.3\r\n4.5,1.0,3.4,2.0\r\n'

# %%
import boto3
client = boto3.client('sagemaker-runtime')
response = client.invoke_endpoint(
    EndpointName="project-x1-staging",
    Body= my_payload_as_csv,
    ContentType = 'text/csv')

# %%
response_body = response['Body']

# %%
ans = response_body.read().decode()

# %%
import boto3

# Create a Boto3 client for S3
s3_client = boto3.client('s3',aws_access_key_id='AKIAUJKJ5ZIQJK6XUY6X', 
                      aws_secret_access_key='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', 
                      region_name='ap-south-1')

# Specify the bucket name
bucket_name = 'iris-data-model'

# List objects in the bucket
response = s3_client.list_objects_v2(Bucket=bucket_name)

# Get the list of objects
objects = response['Contents']

# Sort the objects based on the last modified time in descending order
sorted_objects = sorted(objects, key=lambda obj: obj['LastModified'], reverse=True)

# Fetch the latest CSV file
latest_csv_key = sorted_objects[0]['Key']

# Download the latest CSV file
s3_client.download_file(bucket_name, latest_csv_key, 'latest.csv')

# Print the key and path of the latest CSV file
print('Latest CSV Key:', latest_csv_key)
print('Path of the Downloaded CSV File: latest.csv')
# Out:
# Latest CSV Key: arkansasdf.csv
# Path of the Downloaded CSV File: latest.csv

# %%
import boto3

# Create a Boto3 client for S3
s3_client = boto3.client('s3',aws_access_key_id='AKIAUJKJ5ZIQJK6XUY6X', 
                      aws_secret_access_key='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', 
                      region_name='ap-south-1')

# Specify the bucket name
bucket_name = 'lambda-bucketanna'

# List objects in the bucket
response = s3_client.list_objects_v2(Bucket=bucket_name)

# Get the list of objects
objects = response['Contents']

# Filter CSV files from the objects list
csv_objects = [obj for obj in objects if obj['Key'].lower().endswith('.csv')]

# Sort the CSV objects based on the last modified time in descending order
sorted_csv_objects = sorted(csv_objects, key=lambda obj: obj['LastModified'], reverse=True)

if len(sorted_csv_objects) > 0:
    # Fetch the latest CSV file
    latest_csv_key = sorted_csv_objects[0]['Key']

    # Download the latest CSV file
    s3_client.download_file(bucket_name, latest_csv_key, 'latest.csv')

    # Print the key and path of the latest CSV file
    print('Latest CSV Key:', latest_csv_key)
    print('Path of the Downloaded CSV File: latest.csv')
else:
    print('No CSV files found in the bucket.')
# Out:
# No CSV files found in the bucket.

# %%
import seedir as sd

# %%
path = "C:/Users/annamalai/Downloads/vaibhav's copy code/TimeSeries-Module"

sd.seedir(path=path, style='emoji', exclude_folders=['.git',".ipynb_checkpoints"],exclude_files=[".ipynb"])
# Out:
# 📁 TimeSeries-Module/
# ├─📄 main.py
# ├─📁 Models/
# │ ├─📄 ARIMA.py
# │ ├─📄 LSTM.py
# │ ├─📄 SARIMAX.py
# │ └─📄 XGBOOST.py
# ├─📄 preprocessing.py
# ├─📄 Readme.md
# └─📄 utils.py

# %%
import streamlit_authenticator as stauth
# Out:
# 2023-06-08 15:45:44.282 INFO    numexpr.utils: NumExpr defaulting to 8 threads.

# %%
import psycopg2

#establishing the connection
conn = psycopg2.connect(
   database="postgres", user='postgres', password='anna123456*', host='dbinstance.crhq093vjbni.ap-south-1.rds.amazonaws.com'
)

#Setting auto commit false
conn.autocommit = True

#Creating a cursor object using the cursor() method
cursor = conn.cursor()

#Retrieving data
cursor.execute('''SELECT * from iris''')


result = cursor.fetchall();

column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species', 'predicted_species']

df = pd.DataFrame(result, columns=column_names)


#Commit your changes in the database
conn.commit()

#Closing the connection
conn.close()

df
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species  \
# 0           2.0          0.4           1.0          0.5        0
# 1           1.0          0.7           0.6          0.3        0
# 2           1.2          0.2           2.0          0.5        0
# 3           2.2          0.9           1.0          0.9        0
# 4           3.2          1.9           1.7          0.5        0
#
#    predicted_species
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
import pandas as pd
from faker import Faker
import random

# Initialize the Faker generator
fake = Faker()

# Define the number of rows for the synthetic data
num_rows = 1000

# Generate synthetic data for the given features
data = []
for _ in range(num_rows):
    company_name = fake.company()
    company_size = random.randint(1, 1000)
    industry = fake.job()
    location = fake.city()
    contract_value = random.uniform(1000, 100000)
    recurring_revenue = random.uniform(100, 10000)
    last_transaction_date = fake.date_between(start_date='-2y', end_date='today')
    num_transactions = random.randint(1, 50)
    interactions = random.randint(10, 100)
    revenue_per_customer = recurring_revenue / num_transactions
    num_repeated_purchases = random.randint(0, num_transactions)
    retention_months = random.randint(1, 24)
    retention_date = last_transaction_date + pd.DateOffset(months=retention_months)
    
    # Generate random macroeconomic features
    gdp_growth_rate = random.uniform(-5, 5)
    interest_rate = random.uniform(0, 10)
    inflation_rate = random.uniform(0, 5)
    unemployment_rate = random.uniform(0, 20)
    consumer_confidence_index = random.uniform(0, 100)
    exchange_rate = random.uniform(0.5, 2)
    
    # Append the generated data as a row
    data.append([
        company_name, company_size, industry, location, contract_value, recurring_revenue,
        last_transaction_date, num_transactions, interactions, revenue_per_customer,
        num_repeated_purchases, retention_months, retention_date,
        gdp_growth_rate, interest_rate, inflation_rate, unemployment_rate,
        consumer_confidence_index, exchange_rate
    ])

# Create a DataFrame from the generated data
columns = [
    'Company Name', 'Company Size', 'Industry', 'Location', 'Contract Value', 'Recurring Revenue',
    'Last Transaction Date', 'Num Transactions', 'Interactions', 'Revenue per Customer',
    'Num Repeated Purchases', 'Retention Months', 'Retention Date',
    'GDP Growth Rate', 'Interest Rate', 'Inflation Rate', 'Unemployment Rate',
    'Consumer Confidence Index', 'Exchange Rate'
]
df = pd.DataFrame(data, columns=columns)

# Save the synthetic data to a CSV file
df.to_csv('synthetic_data.csv', index=False)

# %%
df.head()
# Out:
#                     Company Name  Company Size                    Industry  \
# 0       Smith, Peters and Gordon           337                  Geochemist
# 1       Bradley, Potts and Adams           979     Presenter, broadcasting
# 2                  Ball-Figueroa           339        Community pharmacist
# 3                     Hill Group           513       Insurance underwriter
# 4  Patterson, Bautista and Pratt           372  Television camera operator
#
#           Location  Contract Value  Recurring Revenue Last Transaction Date  \
# 0  West Stacyhaven    85565.518027        6151.597559            2022-09-23
# 1        Mcgeeside    58364.900123        7527.737186            2021-06-18
# 2      West Nicole    21507.070154        1346.987817            2022-10-03
# 3    New Elizabeth    32347.762494        6400.321252            2022-06-05
# 4       Andreatown    39464.323817         620.074657            2022-11-26
#
# ...

# %%
import pandas as pd
from faker import Faker
import random

# Initialize the Faker generator
fake = Faker()

# Define the number of rows for the synthetic data
num_rows = 1000

# Generate synthetic data for the given features
data = []
for _ in range(num_rows):
    company_name = fake.company()
    company_size = random.randint(1, 1000)
    industry = fake.job()
    location = fake.city()
    recurring_revenue = random.uniform(100, 10000)
    last_transaction_date = fake.date_between(start_date='-2y', end_date='today')
    num_transactions = random.randint(1, 50)
    interactions = random.randint(10, 100)
    revenue_per_customer = recurring_revenue / num_transactions
    num_repeated_purchases = random.randint(0, num_transactions)
    retention_months = random.randint(1, 24)
    retention_date = last_transaction_date + pd.DateOffset(months=retention_months)
    
    # Generate macroeconomic features
    gdp_growth_rate = random.uniform(0.5, 5.0)
    inflation_rate = random.uniform(1.0, 10.0)
    unemployment_rate = random.uniform(2.0, 15.0)
    
    # Calculate the contract value
    contract_value = recurring_revenue * num_transactions
    
    # Append the generated data as a row
    data.append([
        company_name, company_size, industry, location, contract_value, recurring_revenue,
        last_transaction_date, num_transactions, interactions, revenue_per_customer,
        num_repeated_purchases, retention_months, retention_date,
        gdp_growth_rate, inflation_rate, unemployment_rate
    ])

# Create a DataFrame from the generated data
columns = [
    'Company Name', 'Company Size', 'Industry', 'Location', 'Contract Value', 'Recurring Revenue',
    'Last Transaction Date', 'Num Transactions', 'Interactions', 'Revenue per Customer',
    'Num Repeated Purchases', 'Retention Months', 'Retention Date',
    'GDP Growth Rate', 'Inflation Rate', 'Unemployment Rate'
]
df = pd.DataFrame(data, columns=columns)

# Save the synthetic data to a CSV file
df.to_csv('synthetic_data_2.csv', index=False)
